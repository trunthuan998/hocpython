# %%
import turtle
import datetime
current_time = datetime.datetime.now()
formatted_time = current_time.strftime("%Y-%m-%d_%H-%M-%S")
h = int(current_time.strftime("%H"))
m = int(current_time.strftime("%M"))
s = int(current_time.strftime("%S"))
class DongHo:
    def __init__(self, gio, phut, giay):
        self.gio = gio
        self.phut = phut
        self.giay = giay
    
    
    def ve_dong_ho(self):
        
        # Khởi tạo Turtle
        dong_ho = turtle.Turtle()
        dong_ho.speed(0)  # Đặt tốc độ vẽ nhanh nhất
        
        
        # Vẽ mặt đồng hồ 
        dong_ho.penup()
        dong_ho.goto(0, -200)
        dong_ho.pendown()
        dong_ho.color("black")
        dong_ho.pensize(2)
        dong_ho.circle(200)
            
        for i in range(12):
            angle = math.radians(i * 30)  # Mỗi vạch chia độ cách nhau 30 độ
            x = 180 * math.sin(angle)
            y = 180 * math.cos(angle)
            
            dong_ho.penup()
            dong_ho.goto(0, 0)
            dong_ho.setheading(90)
            dong_ho.pendown()
            
            if i % 3 == 0:
                dong_ho.forward(20)  # Vạch chia độ dài hơn cho các đối số của 3
            else:
                dong_ho.forward(10)  # Vạch chia độ ngắn hơn cho các số còn lại
            
            dong_ho.penup()
            dong_ho.goto(x, y)
            dong_ho.pendown()
            dong_ho.forward(10)  # Độ dài của vạch chia độ

        
        # Vẽ kim giờ
        dong_ho.penup()
        dong_ho.goto(0, 0)
        dong_ho.setheading(90)  # Đặt hướng lên trên
        dong_ho.pendown()
        dong_ho.color("black")
        dong_ho.pensize(4)
        dong_ho.right(30*h)  
        dong_ho.forward(80)  # Độ dài của kim giờ
        
        # Vẽ kim phút
        dong_ho.penup()
        dong_ho.goto(0, 0)
        dong_ho.setheading(90)
        dong_ho.pendown()
        dong_ho.color("black")
        dong_ho.pensize(3)
        dong_ho.right(6*m)  
        dong_ho.forward(100)  # Độ dài của kim phút
        
        # Vẽ kim giây
        dong_ho.penup()
        dong_ho.goto(0, 0)
        dong_ho.setheading(90)
        dong_ho.pendown()
        dong_ho.color("red")
        dong_ho.pensize(1)
        dong_ho.right(6*s)  
        dong_ho.forward(120)  # Độ dài của kim giây
        turtle.done()

DongHo(h,m,s).ve_dong_ho()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[53], line 82
#      79         dong_ho.forward(120)  # Độ dài của kim giây
#      80         turtle.done()
# ---> 82 DongHo(h,m,s).ve_dong_ho()
#
# Cell In[53], line 18, in DongHo.ve_dong_ho(self)
#      15 def ve_dong_ho(self):
#      16
#      17     # Khởi tạo Turtle
# ---> 18     dong_ho = turtle.Turtle()
#      19     dong_ho.speed(0)  # Đặt tốc độ vẽ nhanh nhất
#      22     # Vẽ mặt đồng hồ
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\turtle.py:3831, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3829 if Turtle._screen is None:
#    3830     Turtle._screen = Screen()
# -> 3831 RawTurtle.__init__(self, Turtle._screen,
#    3832                    shape=shape,
#    3833                    undobuffersize=undobuffersize,
#    3834                    visible=visible)
#
# ...
