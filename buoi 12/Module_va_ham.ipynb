# %% [markdown]
# # Function

# %% [markdown]
# ## Function(hàm) là gì?

# %% [markdown]
# Hàm (function) là một khối lệnh đặc biệt, nó được đặt tên, giúp mã chương trình dễ đọc hơn, và có thể gọi để sử dụng ở các nơi khác nhau trong chương trình. Hàm chính là khối lệnh có thể tái sử dụng (reuseable).

# %% [markdown]
# ### Hàm
#
# Cú pháp:
#
# `def <tên hàm>(<tham số)>:
#     //Nội dung hàm`
#
# Gọi hàm:
# `<tên hàm>(<giá trị đầu vào>)`

# %% [markdown]
# ### Ví dụ: Hàm in

# %% [markdown]
# ### Ví dụ: Hàm tính giá trị tuyệt đối

# %%
abs(-5)
# Out:
# 5

# %% [markdown]
# ### Ví dụ: Hàm vẽ hình tròn

# %% [markdown]
# ## Xây dựng và sử dụng hàm trong python

# %% [markdown]
# ### Hàm say_hello

# %%
def say_hello():
    print("hello")
say_hello()
# Out:
# hello

# %% [markdown]
# ### Hàm vẽ cây thông

# %% [markdown]
# ### Thực hành: Viết hàm vẽ ra hình ảnh như dưới đây:
# ![image.png](attachment:image.png)

# %%
import turtle
p = turtle.Turtle()
def ve_bia(a):
    for i in range(6):
        p.circle(a)
        p.penup()
        p.right(90)
        p.forward(10)
        p.pendown()
        p.left(90)
        a += 10
    turtle.done()
    
ve_bia(10)

# %% [markdown]
# ## doc_string cho hàm

# %%
# Hàm tính chu vi hình chữ nhật

# %%
# Hàm xếp loại học sinh

# %% [markdown]
# ## Phạm vi biến

# %%
# Hàm tính tổng các số từ 1 đến 10

# %% [markdown]
# ![image.png](attachment:3c58d507-33ff-4339-8d53-394330dea52e.png)

# %% [markdown]
# ## Đối số của hàm

# %%
# Hàm tính thể tích hình lập phương

# %%
# Hàm xếp loại học sinh

# %% [markdown]
# ### Thực hành: Viết hàm nhận vào một số nguyên và kiểm tra xem số đó có phải là số nguyên tố hay không.

# %% [markdown]
# ## Đối số có giá trị mặc định

# %% [markdown]
# ## Giá trị trả về của hàm

# %% [markdown]
# # return
#
# Cú pháp:
#
# `return <giá trị trả về>`
#
# ##### Lưu ý: Sau khi thực hiện lệnh return, chương trình sẽ thoát khỏi hàm ngay lập tức (những lệnh sau đó không được thực hiện)
#
# Ví dụ:
#
# Hãy viết 1 hàm trả về giá trị trung bình của 2 số bất kỳ

# %% [markdown]
# ![image.png](attachment:29f24d14-fb9f-4b65-a97a-b7ac37d72fb2.png)

# %%
# Hàm tính chiều dài của chuỗi
def str_len(string):
    n = len(string)
    return n

a = str_len("thuan")
print(a)
# Out:
# 5

# %%
# Hàm tính lũy thừa
def c_f(number,so_mu):
    kq = number**so_mu
    return kq
b = c_f(2,3)
print(b)
# Out:
# 8

# %%
# Hàm kiểm tra năm nhuận
def is_leap_year(year):
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        return True
    else:
        return False

year = int(input("Nhập năm: "))
if is_leap_year(year):
    print(year, "là năm nhuận.")
else:
    print(year, "không phải là năm nhuận.")
# Out:
# Nhập năm:  2023
# 2023 không phải là năm nhuận.
