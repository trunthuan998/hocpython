# %% [markdown]
# # Kiểu dữ liệu

# %%
print ("my name is Thuan") # string : str
# Out:
# my name is Thuan

# %%
print (1998) # integers : int
# Out:
# 1998

# %%
print (20.10) # float : float
# Out:
# 20.1

# %%
print (True)  # boolean : bool
print (False)

# %% [markdown]
# # Toán tử

# %%
a = 10 
b = 5 
c = 2.5
d = "Python"
e = "Fundamental"

# %% [markdown]
# ## Toán tử cộng

# %%
print (a + b)
print (a + c)
# Out:
# 15
# 12.5

# %%
print (d + e)
# Out:
# PythonFundamental

# %%
print (a + True)
print (a + False)
# Out:
# 11
# 10

# %% [markdown]
# ## Toán tử trừ

# %%
print (c - a)
# Out:
# -7.5

# %%
print (a - d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print (a - d)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %% [markdown]
# ## Toán tử nhân

# %%
print (c * a)
# Out:
# 25.0

# %%
print (a * d)
# Out:
# PythonPythonPythonPythonPythonPythonPythonPythonPythonPython

# %% [markdown]
# ## Toán tử chia

# %%
print (a/b) # ket qua cua phep chia luon la float
# Out:
# 2.0

# %% [markdown]
# ## Chia lấy dư

# %%
print(b%2) # phep chia lay phan du 
print (b // 2) # phep chia lay phan nguyen, ket qua la int
# Out:
# 1
# 2

# %% [markdown]
# ## Lũy thừa

# %%
print(2**3)
# Out:
# 8

# %% [markdown]
# ## Toán tử quan hệ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:19bff8bf-0456-4093-a4ba-e5f3e827f972.png)

# %% [markdown]
# ## Phép gán

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
salary = 1000
salary = salary + 200 
print(salary)
# Out:
# 1200

# %%
salary = 1000
salary += 200
print(salary)
# Out:
# 1200

# %% [markdown]
# ## Toán tử logic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image (1).png](attachment:d687ff19-87ee-4fe9-8c10-bf0344ad34bb.png)
