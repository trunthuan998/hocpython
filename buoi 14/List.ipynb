# %% [markdown]
# ## Review: type()

# %%
# Python có 4 kiểu dữ liệu cơ bản

# %% [markdown]
# ## list là gì?

# %% [markdown]
# # Ví dụ
# ![image.png](attachment:726665e9-77c3-41ae-8dad-07786d257c65.png)

# %%
# Sử dụng list

# %% [markdown]
# ### Thực hành: Viết chương trình tạo ra một list các string khác nhau và đếm tổng số lượng string dài hơn 3 kí tự

# %%
list = ["45454", "thuan", "ha tien", "123", "thai duong"]
t = 0
for i in list:
    if len(i) > 3:
        t += 1
print(t)
# Out:
# 4

# %% [markdown]
# ### Thực hành 2: Viết chương trình nhận vào 2 list và trả về True nếu 2 list có ít nhất 1 phần tử chung, ngược lại trả về False

# %% [markdown]
# ## Các thao tác cơ bản với list

# %% [markdown]
# ### Kiểm tra độ dài list

# %%
list = ["45454", "thuan", "ha tien", "123", "thai duong"]
print(len(list))
# Out:
# 5

# %% [markdown]
# ### Truy cập phần tử trên list

# %% [markdown]
# ### Thực hành: Tạo một list 10 số tự nhiên và in ra các phần tử trong list

# %%
import random
l = []
for i in range(10):
    a = random.randint(1, 10)
    l += str(a)
print(l)
# Out:
# ['7', '9', '9', '9', '1', '2', '8', '2', '7', '8']

# %% [markdown]
# ### Thực hành 2: Tạo ra một list con chưa 2 phần tử cuối cùng từ list đã tạo ở trên

# %%
 a = l[-2:]
print(a)
# Out:
# ['7', '8']

# %% [markdown]
# ### Cộng list

# %%
a.append('thuan')
print(a)

l.extend(a)
l
# Out:
# ['7', '8', 'thuan', 'thuan', 'thuan']
# ['7',
#  '9',
#  '9',
#  '9',
#  '1',
#  '2',
#  '8',
#  '2',
#  '7',
#  '8',
#  '7',
#  '8',
#  'thuan',
#  'thuan',
#  '7',
#  '8',
#  'thuan',
#  'thuan',
#  'thuan']

# %% [markdown]
# ![image.png](attachment:d593f799-b87f-4d86-a333-97a905bc29c9.png)

# %% [markdown]
# ### Thực hành: Thêm học sinh vào lớp

# %% [markdown]
# ### Kiểm tra phần tử tồn tại trong list

# %%
list = ["45454", "thuan", "ha tien", "123", "thai duong"]
print("thuan" in list)
# Out:
# True

# %% [markdown]
# ### Xóa phần tử khỏi list

# %%
list = ["45454", "thuan", "ha tien", "123", "thai duong"]
list.remove("123")
del list[0]
list
# Out:
# ['thuan', 'ha tien', 'thai duong']

# %% [markdown]
# ![image.png](attachment:cd6782d3-8ed3-41de-871a-9e3b70726f78.png)

# %% [markdown]
# ### Sắp xếp list

# %%
ls = [1,2,5,4,7,9,6]
ls.sort()
ls.sort(reverse = True)
ls
# Out:
# [9, 7, 6, 5, 4, 2, 1]

# %% [markdown]
# ![image.png](attachment:310bed7c-2b13-4ba7-b794-cf85cd7ef843.png)

# %% [markdown]
# ### Làm rỗng list

# %% [markdown]
# ![image.png](attachment:a2eef51e-e798-4fa9-b739-80b26b5ed8d7.png)

# %% [markdown]
# ### Copy list

# %% [markdown]
# ![image.png](attachment:cc0efd82-e704-42f2-b049-81531773c3e9.png)
